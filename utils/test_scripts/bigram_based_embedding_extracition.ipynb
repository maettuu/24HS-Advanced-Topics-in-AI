# %%
# set app as default directory to address imports
import os
import sys
sys.path.append(os.path.join(os.getcwd(), './../../'))

#activate autoreload to easier test classes
# %load_ext autoreload
# %autoreload 2

# %%
from app.services.sparql_graph import SPARQLGraph
from app.config.enums import Environment
graph = SPARQLGraph(Environment.DEV, False)
# Out:
# Metadata loaded successfully from JSON files.
# Initializing SPARQLGraph
# Graph loaded with 94107 triples after 0:00:14.296556

# %%
import nltk
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from sentence_transformers import SentenceTransformer, util
import torch

# Relations as a flat list for embedding
relations = graph.get_relations_labels()

# Load the transformer model (e.g., all-mpnet-base-v2)
model = SentenceTransformer('all-mpnet-base-v2')

# Load the transformer model (e.g., all-mpnet-base-v2)
model = SentenceTransformer('all-mpnet-base-v2')

# Embed the relations and their synonyms into the embedding space
relation_embeddings = model.encode(relations, convert_to_tensor=True)

# Ensure you have the required data for bigrams
nltk.download('punkt')

# Function to extract n-grams (unigrams, bigrams, trigrams)
def extract_ngrams(text):
    # Tokenize the sentence
    tokens = nltk.word_tokenize(text)
    # Remove stop words
    filtered_tokens = [word for word in tokens if word.lower() not in ENGLISH_STOP_WORDS]
    
    # Generate unigrams, bigrams, and trigrams
    unigrams = filtered_tokens
    bigrams = list(nltk.bigrams(filtered_tokens))
    trigrams = list(nltk.trigrams(filtered_tokens))
    
    # Join n-grams into phrases
    unigram_phrases = unigrams
    bigram_phrases = [' '.join(bigram) for bigram in bigrams]
    trigram_phrases = [' '.join(trigram) for trigram in trigrams]
    
    return unigram_phrases, bigram_phrases, trigram_phrases

# Example query
# query = "Who was the screen writer of the movie"
query = "On which day was  released"

# Step 1: Extract unigrams, bigrams, and trigrams
unigrams, bigrams, trigrams = extract_ngrams(query)
print("Unigrams extracted:", unigrams)
print("Bigrams extracted:", bigrams)
print("Trigrams extracted:", trigrams)

# Step 2: Embed each n-gram and find the most similar relation
ngrams = unigrams + bigrams + trigrams
ngrams_embeddings = model.encode(ngrams, convert_to_tensor=True)

# Find the cosine similarities between n-grams and relations
cosine_scores_ngrams = util.pytorch_cos_sim(ngrams_embeddings, relation_embeddings)

# Iterate over each n-gram and print cosine similarity scores for each relation
for i, ngram in enumerate(ngrams):
    print(f"\nCosine similarities for n-gram: '{ngram}'")
    for j, relation in enumerate(relations):
        similarity_score = cosine_scores_ngrams[i, j].item()  # Get the similarity score for the n-gram and relation
        print(f"  Similarity with relation '{relation}': {similarity_score:.4f}")

# Step 3: Find the most similar relation by maximizing over all n-grams
max_scores_ngrams, _ = cosine_scores_ngrams.max(dim=0)
most_similar_idx_ngrams = max_scores_ngrams.argmax()
most_similar_relation_ngrams = relations[most_similar_idx_ngrams]

# Print the cosine similarity and relation for the most similar n-gram
print(f"\nMost similar relation using n-grams: '{most_similar_relation_ngrams}' with cosine similarity: {max_scores_ngrams[most_similar_idx_ngrams].item():.4f}")

# Step 4: Whole sentence comparison
filtered_query_tokens = [word for word in nltk.word_tokenize(query) if word.lower() not in ENGLISH_STOP_WORDS]
filtered_query = ' '.join(filtered_query_tokens)
query_embedding = model.encode(filtered_query, convert_to_tensor=True)

# Find the cosine similarities between the whole query and relations
cosine_scores_sentence = util.pytorch_cos_sim(query_embedding, relation_embeddings)

# Get the index of the most similar relation for the whole sentence
most_similar_idx_sentence = cosine_scores_sentence.argmax()
most_similar_relation_sentence = relations[most_similar_idx_sentence]

# Print the cosine similarity and relation for the whole sentence
print(f"\nCosine similarity using whole sentence: {cosine_scores_sentence[0, most_similar_idx_sentence].item():.4f}")
print(f"Most similar relation using whole sentence: {most_similar_relation_sentence}")

# Step 5: Overall comparison - selecting the highest similarity from all methods
all_scores = torch.cat((max_scores_ngrams, cosine_scores_sentence.flatten()))
all_relations = relations + [most_similar_relation_sentence]

# Get the index of the overall most similar relation
most_similar_idx_overall = all_scores.argmax()
most_similar_relation_overall = all_relations[most_similar_idx_overall]

# Print the final most similar relation and its cosine similarity
print(f"\nOverall most similar relation: '{most_similar_relation_overall}' with cosine similarity: {all_scores[most_similar_idx_overall].item():.4f}")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\adam\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Unigrams extracted: ['day', 'released']
# Bigrams extracted: ['day released']
# Trigrams extracted: []
#
# Cosine similarities for n-gram: 'day'
#   Similarity with relation 'IFCO rating': 0.0765
#   Similarity with relation 'located in present-day administrative territorial entity': 0.0795
#   Similarity with relation 'assessment': 0.2442
#   Similarity with relation 'production company': 0.1486
#   Similarity with relation 'named after': 0.1638
#   Similarity with relation 'place of death': 0.1324
#   Similarity with relation 'ancestral home': 0.1600
#   Similarity with relation 'based on': 0.2089
#   Similarity with relation 'ethnic group': 0.1286
#   Similarity with relation 'location': 0.2160
#   Similarity with relation 'original film format': 0.0788
#   Similarity with relation 'depicts': 0.1865
#   Similarity with relation 'head of state': 0.1213
#   Similarity with relation 'different from': 0.2399
#   Similarity with relation 'narrator': 0.1462
#   Similarity with relation 'sound designer': 0.1025
#   Similarity with relation 'sports discipline competed in': 0.1186
#   Similarity with relation 'edition or translation of': 0.1305
#   Similarity with relation 'industry': 0.1469
#   Similarity with relation 'located in or next to body of water': 0.0082
#   Similarity with relation 'has effect': 0.1877
#   Similarity with relation 'notable work': 0.1209
#   Similarity with relation 'owner of': 0.1333
#   Similarity with relation 'present in work': 0.1890
#   Similarity with relation 'capital': 0.2472
#   Similarity with relation 'place served by transport hub': 0.0290
#   Similarity with relation 'cites work': 0.0276
#   Similarity with relation 'KMRB film rating': 0.0505
#   Similarity with relation 'archives at': 0.2171
#   Similarity with relation 'part of the series': 0.2561
#   Similarity with relation 'applies to jurisdiction': 0.0675
#   Similarity with relation 'distributed by': 0.1189
#   Similarity with relation 'cause of death': 0.0772
#   Similarity with relation 'character designer': 0.1789
#   Similarity with relation 'film editor': 0.0451
#   Similarity with relation 'work location': 0.0754
#   Similarity with relation 'NMHH film rating': 0.0941
#   Similarity with relation 'publisher': 0.1269
#   Similarity with relation 'country for sport': 0.1764
#   Similarity with relation 'copyright representative': 0.0185
#   Similarity with relation 'significant person': 0.1409
#   Similarity with relation 'copyright holder': 0.0013
#   Similarity with relation 'Australian Classification': 0.1384
#   Similarity with relation 'winner': 0.2816
#   Similarity with relation 'INCAA film rating': 0.0810
#   Similarity with relation 'box office': 0.2203
#   Similarity with relation 'represented by': 0.1740
#   Similarity with relation 'language of work or name': 0.1071
#   Similarity with relation 'fabrication method': 0.0512
#   Similarity with relation 'replaced by': 0.2094
#   Similarity with relation 'animator': 0.1791
#   Similarity with relation 'member of sports team': 0.1740
#   Similarity with relation 'after a work by': 0.1542
#   Similarity with relation 'make-up artist': 0.1732
#   Similarity with relation 'filming location': 0.0882
#   Similarity with relation 'original broadcaster': 0.0568
#   Similarity with relation 'operator': 0.1798
#   Similarity with relation 'located on terrain feature': 0.0778
#   Similarity with relation 'part of': 0.2220
#   Similarity with relation 'practiced by': 0.1721
#   Similarity with relation 'follows': 0.1663
#   Similarity with relation 'sexual orientation': 0.1160
#   Similarity with relation 'business model': 0.1353
#   Similarity with relation 'sex or gender': 0.2272
#   Similarity with relation 'described by source': 0.1345
#   Similarity with relation 'film crew member': 0.0836
#   Similarity with relation 'languages spoken, written or signed': 0.0669
#   Similarity with relation 'headquarters location': 0.0512
#   Similarity with relation 'ICAA rating': 0.0674
#   Similarity with relation 'shares border with': 0.0523
#   Similarity with relation 'creator': 0.1849
#   Similarity with relation 'affiliation': 0.1429
#   Similarity with relation 'IMDb ID': 0.0966
#   Similarity with relation 'color': 0.2768
#   Similarity with relation 'broadcast by': 0.1305
#   Similarity with relation 'inspired by': 0.2655
#   Similarity with relation 'unmarried partner': 0.1207
#   Similarity with relation 'executive producer': 0.0747
#   Similarity with relation 'relative': 0.1510
#   Similarity with relation 'partner in business or sport': 0.1001
#   Similarity with relation 'killed by': 0.2137
#   Similarity with relation 'participant': 0.1631
#   Similarity with relation 'has edition or translation': 0.0741
#   Similarity with relation 'musical conductor': 0.0089
#   Similarity with relation 'superhuman feature or ability': 0.0977
#   Similarity with relation 'military branch': 0.0100
#   Similarity with relation 'spouse': 0.2274
#   Similarity with relation 'educated at': 0.1363
#   Similarity with relation 'storyboard artist': 0.0803
#   Similarity with relation 'member of the crew of': 0.1738
#   Similarity with relation 'presented in': 0.2236
#   Similarity with relation 'health specialty': 0.0839
#   Similarity with relation 'child': 0.2199
#   Similarity with relation 'copyright status': 0.0493
#   Similarity with relation 'has pet': 0.1621
#   Similarity with relation 'depicted by': 0.2071
#   Similarity with relation 'sidekick of': 0.1722
#   Similarity with relation 'followed by': 0.1501
#   Similarity with relation 'place of detention': 0.1533
#   Similarity with relation 'Filmiroda rating': 0.1028
#   Similarity with relation 'ClassInd rating': 0.0852
#   Similarity with relation 'EIRIN film rating': 0.0572
#   Similarity with relation 'country of origin': 0.2298
#   Similarity with relation 'student of': 0.0834
#   Similarity with relation 'basin country': 0.0922
#   Similarity with relation 'derivative work': 0.0998
#   Similarity with relation 'lowest point': 0.1545
#   Similarity with relation 'noble title': 0.1427
#   Similarity with relation 'art director': 0.1348
#   Similarity with relation 'has works in the collection': 0.0517
#   Similarity with relation 'MPAA film rating': 0.0420
#   Similarity with relation 'published in': 0.2018
#   Similarity with relation 'writing language': 0.1590
#   Similarity with relation 'permanent resident of': 0.0448
#   Similarity with relation 'movement': 0.2610
#   Similarity with relation 'has quality': 0.1499
#   Similarity with relation 'indigenous to': 0.2427
#   Similarity with relation 'stepparent': 0.1277
#   Similarity with relation 'owned by': 0.1213
#   Similarity with relation 'form of creative work': 0.1313
#   Similarity with relation 'set in period': 0.2088
#   Similarity with relation 'BBFC rating': 0.0639
#   Similarity with relation 'RTC film rating': 0.0128
#   Similarity with relation 'original language of film or TV show': 0.0360
#   Similarity with relation 'uses': 0.1149
#   Similarity with relation 'screenwriter': 0.0635
#   Similarity with relation 'genre': 0.1761
#   Similarity with relation 'father': 0.2022
#   Similarity with relation 'subclass of': 0.1324
#   Similarity with relation 'designed by': 0.1655
#   Similarity with relation 'mother': 0.2297
#   Similarity with relation 'developer': 0.1729
#   Similarity with relation 'instance of': 0.1654
#   Similarity with relation 'http://ddis.ch/atai/tag': 0.0669
#   Similarity with relation 'OFLC classification': 0.0622
#   Similarity with relation 'intended public': 0.1689
#   Similarity with relation 'convicted of': 0.2653
#   Similarity with relation 'Hong Kong film rating': 0.0692
#   Similarity with relation 'capital of': 0.2029
#   Similarity with relation 'operating system': 0.1747
#   Similarity with relation 'RARS rating': 0.0547
#   Similarity with relation 'nominated for': 0.1418
#   Similarity with relation 'KAVI rating': 0.1303
#   Similarity with relation 'FPB rating': 0.0623
#   Similarity with relation 'facet of': 0.1767
#   Similarity with relation 'input method': 0.1261
#   Similarity with relation 'IMDA rating': 0.0897
#   Similarity with relation 'from narrative universe': 0.1860
#   Similarity with relation 'image': 0.2665
#   Similarity with relation 'crew member(s)': 0.0757
#   Similarity with relation 'takes place in fictional universe': 0.1270
#   Similarity with relation 'significant event': 0.1737
#   Similarity with relation 'partially coincident with': 0.0214
#   Similarity with relation 'CNC film rating (France)': 0.0182
#   Similarity with relation 'costume designer': 0.1660
#   Similarity with relation 'home world': 0.2767
#   Similarity with relation 'religion': 0.2387
#   Similarity with relation 'voice actor': 0.1267
#   Similarity with relation 'JMK film rating': 0.0909
#   Similarity with relation 'native language': 0.2289
#   Similarity with relation 'place of publication': 0.1103
#   Similarity with relation 'sport': 0.2373
#   Similarity with relation 'references work, tradition or theory': 0.0060
#   Similarity with relation 'platform': 0.2750
#   Similarity with relation 'given name': 0.1612
#   Similarity with relation 'node description': 0.0666
#   Similarity with relation 'located in the administrative territorial entity': 0.0656
#   Similarity with relation 'head of government': 0.1491
#   Similarity with relation 'country': 0.2936
#   Similarity with relation 'award received': 0.1600
#   Similarity with relation 'diplomatic relation': 0.1621
#   Similarity with relation 'participant in': 0.0957
#   Similarity with relation 'Kijkwijzer rating': 0.1315
#   Similarity with relation 'main subject': 0.1882
#   Similarity with relation 'cast member': 0.1121
#   Similarity with relation 'interested in': 0.0945
#   Similarity with relation 'political ideology': 0.1148
#   Similarity with relation 'located on street': 0.1760
#   Similarity with relation 'distribution format': 0.0594
#   Similarity with relation 'occupation': 0.2192
#   Similarity with relation 'language used': 0.2091
#   Similarity with relation 'manner of death': 0.1185
#   Similarity with relation 'place of birth': 0.1556
#   Similarity with relation 'member of': 0.1864
#   Similarity with relation 'official residence': 0.1209
#   Similarity with relation 'replaces': 0.1183
#   Similarity with relation 'parent organization': 0.0809
#   Similarity with relation 'has cause': 0.1394
#   Similarity with relation 'contributor to the creative work or subject': 0.0119
#   Similarity with relation 'fictional universe described in': 0.0672
#   Similarity with relation 'set during recurring event': 0.1535
#   Similarity with relation 'dedicated to': 0.2591
#   Similarity with relation 'RCQ classification': 0.0399
#   Similarity with relation 'conferred by': 0.1322
#   Similarity with relation 'list of works': 0.0516
#   Similarity with relation 'residence': 0.1670
#   Similarity with relation 'IGAC rating': 0.0186
#   Similarity with relation 'opposite of': 0.1233
#   Similarity with relation 'lifestyle': 0.2586
#   Similarity with relation 'copyright license': 0.0354
#   Similarity with relation 'use': 0.2015
#   Similarity with relation 'influenced by': 0.1009
#   Similarity with relation 'performer': 0.1498
#   Similarity with relation 'FSK film rating': 0.0549
#   Similarity with relation 'official language': 0.2048
#   Similarity with relation 'twinned administrative body': -0.0065
#   Similarity with relation 'scenographer': 0.0953
#   Similarity with relation 'continent': 0.2088
#   Similarity with relation 'said to be the same as': 0.1692
#   Similarity with relation 'aspect ratio': 0.0203
#   Similarity with relation 'choreographer': 0.1307
#   Similarity with relation 'author': 0.0996
#   Similarity with relation 'plot expanded in': 0.0489
#   Similarity with relation 'founded by': 0.1021
#   Similarity with relation 'Medierådet rating': 0.0617
#   Similarity with relation 'BAMID film rating': 0.0960
#   Similarity with relation 'production designer': 0.1388
#   Similarity with relation 'field of work': 0.1066
#   Similarity with relation 'employer': 0.2071
#   Similarity with relation 'place of burial': 0.0970
#   Similarity with relation 'narrative motif': 0.1347
#   Similarity with relation 'node label': 0.0911
#   Similarity with relation 'director / manager': 0.1350
#   Similarity with relation 'first appearance': 0.2423
#   Similarity with relation 'historic county': 0.1184
#   Similarity with relation 'country of citizenship': 0.1271
#   Similarity with relation 'location of formation': 0.1107
#   Similarity with relation 'narrative location': 0.0733
#   Similarity with relation 'collection': 0.1949
#   Similarity with relation 'director': 0.1790
#   Similarity with relation 'product or material produced': 0.0926
#   Similarity with relation 'time period': 0.2748
#   Similarity with relation 'set in environment': 0.1197
#   Similarity with relation 'has part': 0.1095
#   Similarity with relation 'enemy of': 0.2070
#   Similarity with relation 'contains administrative territorial entity': 0.0346
#   Similarity with relation 'http://ddis.ch/atai/rating': 0.1183
#   Similarity with relation 'allegiance': 0.2519
#   Similarity with relation 'public holiday': 0.4366
#   Similarity with relation 'field of this occupation': 0.0775
#   Similarity with relation 'occupant': 0.2128
#   Similarity with relation 'media franchise': 0.1079
#   Similarity with relation 'MTRCB rating': 0.0176
#   Similarity with relation 'medical condition': 0.1510
#   Similarity with relation 'operating area': 0.0848
#   Similarity with relation 'sibling': 0.1942
#   Similarity with relation 'conflict': 0.2604
#   Similarity with relation 'CNC film rating (Romania)': 0.0232
#   Similarity with relation 'season': 0.2497
#   Similarity with relation 'characters': 0.1567
#   Similarity with relation 'student': 0.0965
#   Similarity with relation 'presenter': 0.1358
#   Similarity with relation 'quotes work': 0.1655
#   Similarity with relation 'director of photography': 0.1201
#   Similarity with relation 'publication date': 0.2422
#
# Cosine similarities for n-gram: 'released'
#   Similarity with relation 'IFCO rating': 0.1001
#   Similarity with relation 'located in present-day administrative territorial entity': 0.0463
#   Similarity with relation 'assessment': 0.2256
#   Similarity with relation 'production company': 0.2657
#   Similarity with relation 'named after': 0.1835
#   Similarity with relation 'place of death': 0.1442
#   Similarity with relation 'ancestral home': 0.0877
#   Similarity with relation 'based on': 0.1661
#   Similarity with relation 'ethnic group': 0.1481
#   Similarity with relation 'location': 0.2633
#   Similarity with relation 'original film format': 0.1828
#   Similarity with relation 'depicts': 0.2064
#   Similarity with relation 'head of state': 0.1059
#   Similarity with relation 'different from': 0.2601
#   Similarity with relation 'narrator': 0.1852
#   Similarity with relation 'sound designer': 0.1826
#   Similarity with relation 'sports discipline competed in': 0.1053
#   Similarity with relation 'edition or translation of': 0.2519
#   Similarity with relation 'industry': 0.1678
#   Similarity with relation 'located in or next to body of water': -0.0237
#   Similarity with relation 'has effect': 0.2455
#   Similarity with relation 'notable work': 0.1724
#   Similarity with relation 'owner of': 0.2051
#   Similarity with relation 'present in work': 0.1852
#   Similarity with relation 'capital': 0.1622
#   Similarity with relation 'place served by transport hub': 0.0794
#   Similarity with relation 'cites work': 0.1377
#   Similarity with relation 'KMRB film rating': 0.1683
#   Similarity with relation 'archives at': 0.2757
#   Similarity with relation 'part of the series': 0.2426
#   Similarity with relation 'applies to jurisdiction': 0.1292
#   Similarity with relation 'distributed by': 0.4165
#   Similarity with relation 'cause of death': 0.0879
#   Similarity with relation 'character designer': 0.1603
#   Similarity with relation 'film editor': 0.1880
#   Similarity with relation 'work location': 0.0945
#   Similarity with relation 'NMHH film rating': 0.1561
#   Similarity with relation 'publisher': 0.3751
#   Similarity with relation 'country for sport': 0.1231
#   Similarity with relation 'copyright representative': 0.2137
#   Similarity with relation 'significant person': 0.1287
#   Similarity with relation 'copyright holder': 0.2148
#   Similarity with relation 'Australian Classification': 0.1122
#   Similarity with relation 'winner': 0.2723
#   Similarity with relation 'INCAA film rating': 0.1382
#   Similarity with relation 'box office': 0.2858
#   Similarity with relation 'represented by': 0.2065
#   Similarity with relation 'language of work or name': 0.1090
#   Similarity with relation 'fabrication method': 0.0961
#   Similarity with relation 'replaced by': 0.3256
#   Similarity with relation 'animator': 0.2143
#   Similarity with relation 'member of sports team': 0.1773
#   Similarity with relation 'after a work by': 0.2745
#   Similarity with relation 'make-up artist': 0.1842
#   Similarity with relation 'filming location': 0.1003
#   Similarity with relation 'original broadcaster': 0.1685
#   Similarity with relation 'operator': 0.2332
#   Similarity with relation 'located on terrain feature': 0.0543
#   Similarity with relation 'part of': 0.1233
#   Similarity with relation 'practiced by': 0.2323
#   Similarity with relation 'follows': 0.2108
#   Similarity with relation 'sexual orientation': 0.1091
#   Similarity with relation 'business model': 0.0932
#   Similarity with relation 'sex or gender': 0.1545
#   Similarity with relation 'described by source': 0.2529
#   Similarity with relation 'film crew member': 0.1866
#   Similarity with relation 'languages spoken, written or signed': 0.0922
#   Similarity with relation 'headquarters location': 0.1019
#   Similarity with relation 'ICAA rating': 0.0637
#   Similarity with relation 'shares border with': 0.0183
#   Similarity with relation 'creator': 0.3560
#   Similarity with relation 'affiliation': 0.2180
#   Similarity with relation 'IMDb ID': 0.2715
#   Similarity with relation 'color': 0.1481
#   Similarity with relation 'broadcast by': 0.3198
#   Similarity with relation 'inspired by': 0.1465
#   Similarity with relation 'unmarried partner': 0.1703
#   Similarity with relation 'executive producer': 0.1768
#   Similarity with relation 'relative': 0.1655
#   Similarity with relation 'partner in business or sport': 0.0374
#   Similarity with relation 'killed by': 0.3132
#   Similarity with relation 'participant': 0.1867
#   Similarity with relation 'has edition or translation': 0.2008
#   Similarity with relation 'musical conductor': 0.1470
#   Similarity with relation 'superhuman feature or ability': 0.0467
#   Similarity with relation 'military branch': 0.0977
#   Similarity with relation 'spouse': 0.1589
#   Similarity with relation 'educated at': 0.2034
#   Similarity with relation 'storyboard artist': 0.1243
#   Similarity with relation 'member of the crew of': 0.2329
#   Similarity with relation 'presented in': 0.3035
#   Similarity with relation 'health specialty': 0.0799
#   Similarity with relation 'child': 0.2033
#   Similarity with relation 'copyright status': 0.2595
#   Similarity with relation 'has pet': 0.1957
#   Similarity with relation 'depicted by': 0.2365
#   Similarity with relation 'sidekick of': 0.1445
#   Similarity with relation 'followed by': 0.2218
#   Similarity with relation 'place of detention': 0.2097
#   Similarity with relation 'Filmiroda rating': 0.1732
#   Similarity with relation 'ClassInd rating': 0.1098
#   Similarity with relation 'EIRIN film rating': 0.1789
#   Similarity with relation 'country of origin': 0.2139
#   Similarity with relation 'student of': 0.1735
#   Similarity with relation 'basin country': 0.0459
#   Similarity with relation 'derivative work': 0.2482
#   Similarity with relation 'lowest point': 0.1465
#   Similarity with relation 'noble title': 0.2126
#   Similarity with relation 'art director': 0.2032
#   Similarity with relation 'has works in the collection': 0.2355
#   Similarity with relation 'MPAA film rating': 0.1326
#   Similarity with relation 'published in': 0.3981
#   Similarity with relation 'writing language': 0.1023
#   Similarity with relation 'permanent resident of': 0.1194
#   Similarity with relation 'movement': 0.2149
#   Similarity with relation 'has quality': 0.1578
#   Similarity with relation 'indigenous to': 0.1669
#   Similarity with relation 'stepparent': 0.1464
#   Similarity with relation 'owned by': 0.2445
#   Similarity with relation 'form of creative work': 0.0942
#   Similarity with relation 'set in period': 0.1712
#   Similarity with relation 'BBFC rating': 0.1060
#   Similarity with relation 'RTC film rating': 0.1057
#   Similarity with relation 'original language of film or TV show': 0.0320
#   Similarity with relation 'uses': 0.1935
#   Similarity with relation 'screenwriter': 0.1794
#   Similarity with relation 'genre': 0.2159
#   Similarity with relation 'father': 0.1917
#   Similarity with relation 'subclass of': 0.0898
#   Similarity with relation 'designed by': 0.3115
#   Similarity with relation 'mother': 0.1920
#   Similarity with relation 'developer': 0.2731
#   Similarity with relation 'instance of': 0.1078
#   Similarity with relation 'http://ddis.ch/atai/tag': 0.1792
#   Similarity with relation 'OFLC classification': 0.0551
#   Similarity with relation 'intended public': 0.3645
#   Similarity with relation 'convicted of': 0.3477
#   Similarity with relation 'Hong Kong film rating': 0.1654
#   Similarity with relation 'capital of': 0.1229
#   Similarity with relation 'operating system': 0.1787
#   Similarity with relation 'RARS rating': 0.1140
#   Similarity with relation 'nominated for': 0.2930
#   Similarity with relation 'KAVI rating': 0.1670
#   Similarity with relation 'FPB rating': 0.2118
#   Similarity with relation 'facet of': 0.0842
#   Similarity with relation 'input method': 0.1099
#   Similarity with relation 'IMDA rating': 0.1098
#   Similarity with relation 'from narrative universe': 0.1837
#   Similarity with relation 'image': 0.2262
#   Similarity with relation 'crew member(s)': 0.1439
#   Similarity with relation 'takes place in fictional universe': 0.0554
#   Similarity with relation 'significant event': 0.1223
#   Similarity with relation 'partially coincident with': 0.0436
#   Similarity with relation 'CNC film rating (France)': 0.0958
#   Similarity with relation 'costume designer': 0.1973
#   Similarity with relation 'home world': 0.1943
#   Similarity with relation 'religion': 0.1131
#   Similarity with relation 'voice actor': 0.1291
#   Similarity with relation 'JMK film rating': 0.1679
#   Similarity with relation 'native language': 0.1106
#   Similarity with relation 'place of publication': 0.2712
#   Similarity with relation 'sport': 0.1584
#   Similarity with relation 'references work, tradition or theory': 0.0293
#   Similarity with relation 'platform': 0.2703
#   Similarity with relation 'given name': 0.3443
#   Similarity with relation 'node description': 0.0987
#   Similarity with relation 'located in the administrative territorial entity': 0.0687
#   Similarity with relation 'head of government': 0.1281
#   Similarity with relation 'country': 0.1578
#   Similarity with relation 'award received': 0.4355
#   Similarity with relation 'diplomatic relation': 0.1058
#   Similarity with relation 'participant in': 0.1370
#   Similarity with relation 'Kijkwijzer rating': 0.1477
#   Similarity with relation 'main subject': 0.1317
#   Similarity with relation 'cast member': 0.1925
#   Similarity with relation 'interested in': 0.2322
#   Similarity with relation 'political ideology': 0.0881
#   Similarity with relation 'located on street': 0.2355
#   Similarity with relation 'distribution format': 0.2156
#   Similarity with relation 'occupation': 0.2162
#   Similarity with relation 'language used': 0.2139
#   Similarity with relation 'manner of death': 0.1257
#   Similarity with relation 'place of birth': 0.1169
#   Similarity with relation 'member of': 0.2438
#   Similarity with relation 'official residence': 0.0828
#   Similarity with relation 'replaces': 0.1694
#   Similarity with relation 'parent organization': 0.0985
#   Similarity with relation 'has cause': 0.1204
#   Similarity with relation 'contributor to the creative work or subject': 0.1667
#   Similarity with relation 'fictional universe described in': 0.0255
#   Similarity with relation 'set during recurring event': 0.0593
#   Similarity with relation 'dedicated to': 0.3548
#   Similarity with relation 'RCQ classification': 0.0168
#   Similarity with relation 'conferred by': 0.2642
#   Similarity with relation 'list of works': 0.1850
#   Similarity with relation 'residence': 0.1339
#   Similarity with relation 'IGAC rating': 0.0771
#   Similarity with relation 'opposite of': 0.0938
#   Similarity with relation 'lifestyle': 0.2102
#   Similarity with relation 'copyright license': 0.2049
#   Similarity with relation 'use': 0.2615
#   Similarity with relation 'influenced by': 0.1268
#   Similarity with relation 'performer': 0.2438
#   Similarity with relation 'FSK film rating': 0.1833
#   Similarity with relation 'official language': 0.1440
#   Similarity with relation 'twinned administrative body': -0.0057
#   Similarity with relation 'scenographer': 0.1197
#   Similarity with relation 'continent': 0.1832
#   Similarity with relation 'said to be the same as': 0.2434
#   Similarity with relation 'aspect ratio': 0.0872
#   Similarity with relation 'choreographer': 0.1999
#   Similarity with relation 'author': 0.2616
#   Similarity with relation 'plot expanded in': 0.1630
#   Similarity with relation 'founded by': 0.1440
#   Similarity with relation 'Medierådet rating': 0.1044
#   Similarity with relation 'BAMID film rating': 0.1443
#   Similarity with relation 'production designer': 0.2099
#   Similarity with relation 'field of work': 0.1510
#   Similarity with relation 'employer': 0.2277
#   Similarity with relation 'place of burial': 0.0897
#   Similarity with relation 'narrative motif': 0.0731
#   Similarity with relation 'node label': 0.1322
#   Similarity with relation 'director / manager': 0.2158
#   Similarity with relation 'first appearance': 0.2470
#   Similarity with relation 'historic county': 0.0974
#   Similarity with relation 'country of citizenship': 0.0842
#   Similarity with relation 'location of formation': 0.1864
#   Similarity with relation 'narrative location': 0.0771
#   Similarity with relation 'collection': 0.2194
#   Similarity with relation 'director': 0.2913
#   Similarity with relation 'product or material produced': 0.1565
#   Similarity with relation 'time period': 0.2272
#   Similarity with relation 'set in environment': 0.0513
#   Similarity with relation 'has part': 0.1276
#   Similarity with relation 'enemy of': 0.2006
#   Similarity with relation 'contains administrative territorial entity': 0.0204
#   Similarity with relation 'http://ddis.ch/atai/rating': 0.1783
#   Similarity with relation 'allegiance': 0.2641
#   Similarity with relation 'public holiday': 0.3199
#   Similarity with relation 'field of this occupation': 0.1275
#   Similarity with relation 'occupant': 0.1717
#   Similarity with relation 'media franchise': 0.1763
#   Similarity with relation 'MTRCB rating': 0.0736
#   Similarity with relation 'medical condition': 0.1517
#   Similarity with relation 'operating area': 0.0693
#   Similarity with relation 'sibling': 0.1418
#   Similarity with relation 'conflict': 0.1601
#   Similarity with relation 'CNC film rating (Romania)': 0.0875
#   Similarity with relation 'season': 0.2075
#   Similarity with relation 'characters': 0.2068
#   Similarity with relation 'student': 0.1768
#   Similarity with relation 'presenter': 0.1786
#   Similarity with relation 'quotes work': 0.2135
#   Similarity with relation 'director of photography': 0.1796
#   Similarity with relation 'publication date': 0.4109
#
# Cosine similarities for n-gram: 'day released'
#   Similarity with relation 'IFCO rating': 0.0713
#   Similarity with relation 'located in present-day administrative territorial entity': 0.0058
#   Similarity with relation 'assessment': 0.1754
#   Similarity with relation 'production company': 0.2186
#   Similarity with relation 'named after': 0.1522
#   Similarity with relation 'place of death': 0.1037
#   Similarity with relation 'ancestral home': 0.1008
#   Similarity with relation 'based on': 0.1741
#   Similarity with relation 'ethnic group': 0.1069
#   Similarity with relation 'location': 0.2126
#   Similarity with relation 'original film format': 0.1624
#   Similarity with relation 'depicts': 0.1224
#   Similarity with relation 'head of state': 0.0435
#   Similarity with relation 'different from': 0.1898
#   Similarity with relation 'narrator': 0.1578
#   Similarity with relation 'sound designer': 0.1268
#   Similarity with relation 'sports discipline competed in': 0.0755
#   Similarity with relation 'edition or translation of': 0.2234
#   Similarity with relation 'industry': 0.1116
#   Similarity with relation 'located in or next to body of water': -0.0395
#   Similarity with relation 'has effect': 0.1793
#   Similarity with relation 'notable work': 0.1563
#   Similarity with relation 'owner of': 0.1165
#   Similarity with relation 'present in work': 0.1887
#   Similarity with relation 'capital': 0.1532
#   Similarity with relation 'place served by transport hub': 0.0179
#   Similarity with relation 'cites work': 0.0868
#   Similarity with relation 'KMRB film rating': 0.1506
#   Similarity with relation 'archives at': 0.2366
#   Similarity with relation 'part of the series': 0.2540
#   Similarity with relation 'applies to jurisdiction': 0.0432
#   Similarity with relation 'distributed by': 0.2134
#   Similarity with relation 'cause of death': 0.0779
#   Similarity with relation 'character designer': 0.1624
#   Similarity with relation 'film editor': 0.1215
#   Similarity with relation 'work location': 0.0860
#   Similarity with relation 'NMHH film rating': 0.1703
#   Similarity with relation 'publisher': 0.2522
#   Similarity with relation 'country for sport': 0.0672
#   Similarity with relation 'copyright representative': 0.0852
#   Similarity with relation 'significant person': 0.1086
#   Similarity with relation 'copyright holder': 0.0794
#   Similarity with relation 'Australian Classification': 0.1334
#   Similarity with relation 'winner': 0.1399
#   Similarity with relation 'INCAA film rating': 0.1444
#   Similarity with relation 'box office': 0.3232
#   Similarity with relation 'represented by': 0.1211
#   Similarity with relation 'language of work or name': 0.1068
#   Similarity with relation 'fabrication method': 0.0309
#   Similarity with relation 'replaced by': 0.1533
#   Similarity with relation 'animator': 0.1542
#   Similarity with relation 'member of sports team': 0.0840
#   Similarity with relation 'after a work by': 0.2045
#   Similarity with relation 'make-up artist': 0.1810
#   Similarity with relation 'filming location': 0.1146
#   Similarity with relation 'original broadcaster': 0.0849
#   Similarity with relation 'operator': 0.1533
#   Similarity with relation 'located on terrain feature': 0.0622
#   Similarity with relation 'part of': 0.1340
#   Similarity with relation 'practiced by': 0.1276
#   Similarity with relation 'follows': 0.1214
#   Similarity with relation 'sexual orientation': 0.0529
#   Similarity with relation 'business model': 0.1002
#   Similarity with relation 'sex or gender': 0.1500
#   Similarity with relation 'described by source': 0.1711
#   Similarity with relation 'film crew member': 0.1170
#   Similarity with relation 'languages spoken, written or signed': 0.0770
#   Similarity with relation 'headquarters location': 0.0533
#   Similarity with relation 'ICAA rating': 0.0655
#   Similarity with relation 'shares border with': -0.0030
#   Similarity with relation 'creator': 0.2283
#   Similarity with relation 'affiliation': 0.1095
#   Similarity with relation 'IMDb ID': 0.2048
#   Similarity with relation 'color': 0.1685
#   Similarity with relation 'broadcast by': 0.1915
#   Similarity with relation 'inspired by': 0.1327
#   Similarity with relation 'unmarried partner': 0.0787
#   Similarity with relation 'executive producer': 0.1202
#   Similarity with relation 'relative': 0.0858
#   Similarity with relation 'partner in business or sport': 0.0215
#   Similarity with relation 'killed by': 0.1700
#   Similarity with relation 'participant': 0.1384
#   Similarity with relation 'has edition or translation': 0.1905
#   Similarity with relation 'musical conductor': 0.0225
#   Similarity with relation 'superhuman feature or ability': 0.0463
#   Similarity with relation 'military branch': -0.0080
#   Similarity with relation 'spouse': 0.1085
#   Similarity with relation 'educated at': 0.0960
#   Similarity with relation 'storyboard artist': 0.0981
#   Similarity with relation 'member of the crew of': 0.1897
#   Similarity with relation 'presented in': 0.2121
#   Similarity with relation 'health specialty': 0.0729
#   Similarity with relation 'child': 0.1169
#   Similarity with relation 'copyright status': 0.1713
#   Similarity with relation 'has pet': 0.1203
#   Similarity with relation 'depicted by': 0.1787
#   Similarity with relation 'sidekick of': 0.1192
#   Similarity with relation 'followed by': 0.1369
#   Similarity with relation 'place of detention': 0.1411
#   Similarity with relation 'Filmiroda rating': 0.1404
#   Similarity with relation 'ClassInd rating': 0.0654
#   Similarity with relation 'EIRIN film rating': 0.1412
#   Similarity with relation 'country of origin': 0.1907
#   Similarity with relation 'student of': 0.0477
#   Similarity with relation 'basin country': 0.0254
#   Similarity with relation 'derivative work': 0.2030
#   Similarity with relation 'lowest point': 0.1634
#   Similarity with relation 'noble title': 0.0928
#   Similarity with relation 'art director': 0.1595
#   Similarity with relation 'has works in the collection': 0.1818
#   Similarity with relation 'MPAA film rating': 0.1228
#   Similarity with relation 'published in': 0.3494
#   Similarity with relation 'writing language': 0.0983
#   Similarity with relation 'permanent resident of': -0.0012
#   Similarity with relation 'movement': 0.2191
#   Similarity with relation 'has quality': 0.1208
#   Similarity with relation 'indigenous to': 0.1588
#   Similarity with relation 'stepparent': 0.1137
#   Similarity with relation 'owned by': 0.1396
#   Similarity with relation 'form of creative work': 0.1145
#   Similarity with relation 'set in period': 0.2406
#   Similarity with relation 'BBFC rating': 0.0357
#   Similarity with relation 'RTC film rating': 0.0670
#   Similarity with relation 'original language of film or TV show': 0.0622
#   Similarity with relation 'uses': 0.1076
#   Similarity with relation 'screenwriter': 0.0963
#   Similarity with relation 'genre': 0.2353
#   Similarity with relation 'father': 0.1428
#   Similarity with relation 'subclass of': 0.0948
#   Similarity with relation 'designed by': 0.1941
#   Similarity with relation 'mother': 0.1447
#   Similarity with relation 'developer': 0.2048
#   Similarity with relation 'instance of': 0.0843
#   Similarity with relation 'http://ddis.ch/atai/tag': 0.0925
#   Similarity with relation 'OFLC classification': 0.0712
#   Similarity with relation 'intended public': 0.2346
#   Similarity with relation 'convicted of': 0.2260
#   Similarity with relation 'Hong Kong film rating': 0.1938
#   Similarity with relation 'capital of': 0.1067
#   Similarity with relation 'operating system': 0.1897
#   Similarity with relation 'RARS rating': 0.0464
#   Similarity with relation 'nominated for': 0.1460
#   Similarity with relation 'KAVI rating': 0.1336
#   Similarity with relation 'FPB rating': 0.1084
#   Similarity with relation 'facet of': 0.1166
#   Similarity with relation 'input method': 0.0630
#   Similarity with relation 'IMDA rating': 0.1040
#   Similarity with relation 'from narrative universe': 0.2053
#   Similarity with relation 'image': 0.1440
#   Similarity with relation 'crew member(s)': 0.0738
#   Similarity with relation 'takes place in fictional universe': 0.1224
#   Similarity with relation 'significant event': 0.1704
#   Similarity with relation 'partially coincident with': 0.0130
#   Similarity with relation 'CNC film rating (France)': 0.0597
#   Similarity with relation 'costume designer': 0.1513
#   Similarity with relation 'home world': 0.2553
#   Similarity with relation 'religion': 0.1315
#   Similarity with relation 'voice actor': 0.1198
#   Similarity with relation 'JMK film rating': 0.1675
#   Similarity with relation 'native language': 0.1493
#   Similarity with relation 'place of publication': 0.2073
#   Similarity with relation 'sport': 0.1163
#   Similarity with relation 'references work, tradition or theory': 0.0222
#   Similarity with relation 'platform': 0.2877
#   Similarity with relation 'given name': 0.1864
#   Similarity with relation 'node description': 0.0621
#   Similarity with relation 'located in the administrative territorial entity': 0.0190
#   Similarity with relation 'head of government': 0.0593
#   Similarity with relation 'country': 0.1916
#   Similarity with relation 'award received': 0.2040
#   Similarity with relation 'diplomatic relation': 0.0684
#   Similarity with relation 'participant in': 0.0791
#   Similarity with relation 'Kijkwijzer rating': 0.1393
#   Similarity with relation 'main subject': 0.1706
#   Similarity with relation 'cast member': 0.1490
#   Similarity with relation 'interested in': 0.1556
#   Similarity with relation 'political ideology': 0.0720
#   Similarity with relation 'located on street': 0.1759
#   Similarity with relation 'distribution format': 0.1550
#   Similarity with relation 'occupation': 0.1478
#   Similarity with relation 'language used': 0.1693
#   Similarity with relation 'manner of death': 0.0729
#   Similarity with relation 'place of birth': 0.1458
#   Similarity with relation 'member of': 0.1383
#   Similarity with relation 'official residence': 0.0442
#   Similarity with relation 'replaces': 0.0550
#   Similarity with relation 'parent organization': 0.1002
#   Similarity with relation 'has cause': 0.0775
#   Similarity with relation 'contributor to the creative work or subject': 0.0769
#   Similarity with relation 'fictional universe described in': 0.0454
#   Similarity with relation 'set during recurring event': 0.1417
#   Similarity with relation 'dedicated to': 0.2936
#   Similarity with relation 'RCQ classification': 0.0095
#   Similarity with relation 'conferred by': 0.0893
#   Similarity with relation 'list of works': 0.1707
#   Similarity with relation 'residence': 0.1152
#   Similarity with relation 'IGAC rating': -0.0046
#   Similarity with relation 'opposite of': 0.0359
#   Similarity with relation 'lifestyle': 0.2071
#   Similarity with relation 'copyright license': 0.1196
#   Similarity with relation 'use': 0.1644
#   Similarity with relation 'influenced by': 0.0920
#   Similarity with relation 'performer': 0.1673
#   Similarity with relation 'FSK film rating': 0.1275
#   Similarity with relation 'official language': 0.1745
#   Similarity with relation 'twinned administrative body': -0.0810
#   Similarity with relation 'scenographer': 0.0896
#   Similarity with relation 'continent': 0.1691
#   Similarity with relation 'said to be the same as': 0.1863
#   Similarity with relation 'aspect ratio': 0.0134
#   Similarity with relation 'choreographer': 0.1430
#   Similarity with relation 'author': 0.1702
#   Similarity with relation 'plot expanded in': 0.1138
#   Similarity with relation 'founded by': 0.0866
#   Similarity with relation 'Medierådet rating': 0.0689
#   Similarity with relation 'BAMID film rating': 0.1372
#   Similarity with relation 'production designer': 0.1816
#   Similarity with relation 'field of work': 0.1164
#   Similarity with relation 'employer': 0.1468
#   Similarity with relation 'place of burial': 0.0658
#   Similarity with relation 'narrative motif': 0.1177
#   Similarity with relation 'node label': 0.1186
#   Similarity with relation 'director / manager': 0.1641
#   Similarity with relation 'first appearance': 0.2573
#   Similarity with relation 'historic county': 0.0933
#   Similarity with relation 'country of citizenship': 0.0874
#   Similarity with relation 'location of formation': 0.1627
#   Similarity with relation 'narrative location': 0.1082
#   Similarity with relation 'collection': 0.2167
#   Similarity with relation 'director': 0.2215
#   Similarity with relation 'product or material produced': 0.0738
#   Similarity with relation 'time period': 0.2554
#   Similarity with relation 'set in environment': 0.0859
#   Similarity with relation 'has part': 0.0909
#   Similarity with relation 'enemy of': 0.1426
#   Similarity with relation 'contains administrative territorial entity': -0.0074
#   Similarity with relation 'http://ddis.ch/atai/rating': 0.1349
#   Similarity with relation 'allegiance': 0.2229
#   Similarity with relation 'public holiday': 0.4165
#   Similarity with relation 'field of this occupation': 0.0646
#   Similarity with relation 'occupant': 0.1377
#   Similarity with relation 'media franchise': 0.1097
#   Similarity with relation 'MTRCB rating': 0.0277
#   Similarity with relation 'medical condition': 0.1113
#   Similarity with relation 'operating area': 0.0477
#   Similarity with relation 'sibling': 0.1204
#   Similarity with relation 'conflict': 0.1769
#   Similarity with relation 'CNC film rating (Romania)': 0.0497
#   Similarity with relation 'season': 0.2087
#   Similarity with relation 'characters': 0.1633
#   Similarity with relation 'student': 0.0594
#   Similarity with relation 'presenter': 0.1149
#   Similarity with relation 'quotes work': 0.1475
#   Similarity with relation 'director of photography': 0.1437
#   Similarity with relation 'publication date': 0.4231
#
# Most similar relation using n-grams: 'public holiday' with cosine similarity: 0.4366
#
# Cosine similarity using whole sentence: 0.4231
# Most similar relation using whole sentence: publication date
#
# Overall most similar relation: 'public holiday' with cosine similarity: 0.4366
