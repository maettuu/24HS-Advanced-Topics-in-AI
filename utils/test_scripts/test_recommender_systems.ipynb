# %%
import pandas as pd
from surprise import Dataset, Reader, SVD, KNNBasic
from surprise.model_selection import train_test_split

# %%
movie_data = pd.read_csv("../useful_dataset/recommendations/movies.csv")
rating_data = pd.read_csv("../useful_dataset/recommendations/ratings.csv")

# %%
svd_model = SVD(42)

# Prepare data for the Surprise library
reader = Reader(rating_scale=(0.5, 5))
data = Dataset.load_from_df(rating_data[['userId', 'movieId', 'rating']], reader)

# Split into training and testing sets
trainset, _ = train_test_split(data, test_size=.2)

# Train the SVD model
svd_model.fit(trainset)

# %%
# Train the KNN model
sim_options = {'name': 'cosine', 'user_based': False}  # Item-based similarity
knn_model = KNNBasic(sim_options=sim_options)
knn_model.fit(trainset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
def recommend_movies(self, liked_movie, top_n=10):
    # Find movieId of liked_movie
    # self._load_data()
    movie = self.movie_data[self.movie_data['title'].str.contains(liked_movie, case=False)]
    if len(movie) == 0:
        return "Movie not found in database"

    liked_movie_id = movie['movieId'].values[0]

    # Predict ratings for all movies
    all_movie_ids = self.movie_data['movieId'].unique()
    predicted_ratings = [(mid, self.svd_model.predict(uid=1, iid=mid).est) for mid in all_movie_ids]

    # Sort by estimated rating
    sorted_predictions = sorted(predicted_ratings, key=lambda x: x[1], reverse=True)
    best_match = next((mid for mid, _ in sorted_predictions if mid != liked_movie_id), None)

    # Get the title of the best match
    best_match_title = self.movie_data[self.movie_data['movieId'] == best_match]['title'].values[0:top_n]

    # Filter out the liked movie and fetch titles
    # recommendations = [(self.movie_data[self.movie_data['movieId'] == mid]['title'].values[0], score) for mid, score
    #                    in sorted_predictions if mid != liked_movie_id][:top_n]

    return best_match_title

# %%
def recommend_movies_using_kkn(self, liked_movie, top_n=10):
    """Recommend movies similar to the liked_movie."""
    # Find the movie ID
    liked_movie_row = self.movie_data[self.movie_data['title'].str.contains(liked_movie, case=False)]
    if liked_movie_row.empty:
        return "Movie not found in database."

    liked_movie_id = liked_movie_row['movieId'].values[0]

    # Get the inner ID for the liked movie
    liked_movie_inner_id = self.knn_model.trainset.to_inner_iid(liked_movie_id)

    # Find neighbors
    neighbors = self.knn_model.get_neighbors(liked_movie_inner_id, k=top_n)

    # Convert inner IDs to movie IDs
    recommended_ids = [self.knn_model.trainset.to_raw_iid(inner_id) for inner_id in neighbors]

    # Fetch titles for recommended movie IDs
    recommended_titles = self.movie_data[self.movie_data['movieId'].isin(recommended_ids)]['title'].tolist()

    return recommended_titles

# %% [markdown]
# # Version 253156714532451

# %%
from surprise import Dataset, Reader, KNNBasic
from surprise.model_selection import train_test_split
from surprise import accuracy
import pandas as pd
import numpy as np

# %%
# Load the MovieLens dataset
ratings_file_path = "../useful_dataset/recommendations/ratings.csv"  # Path to MovieLens ratings.csv
movies_file_path = "../useful_dataset/recommendations/movies.csv"  # Path to MovieLens movies.csv
reader = Reader(line_format='user item rating timestamp', sep=',', skip_lines=1)
data = Dataset.load_from_file(ratings_file_path, reader=reader)

# %%
# Load movies data to get movie names
df_movies = pd.read_csv(movies_file_path)
movie_id_to_name = dict(zip(df_movies['movieId'], df_movies['title']))
movie_name_to_id = dict(zip(df_movies['title'], df_movies['movieId']))

# %%
# Ensure selected movies are part of the training set
selected_movie_ids = [movie_name_to_id.get(name) for name in ["Toy Story (1995)", "Jumanji (1995)"] if name in movie_name_to_id]
filtered_ratings = data.raw_ratings
filtered_ratings = [rating for rating in filtered_ratings if rating[1] in selected_movie_ids]
data.raw_ratings = filtered_ratings + data.raw_ratings  # Adding the selected movies to ensure they're part of the dataset

# %%
# Split the data into training and test sets
trainset, testset = train_test_split(data, test_size=0.2)

# %%
# Use KNNBasic algorithm to train a collaborative filtering model
sim_options = {
    'name': 'cosine',
    'user_based': False  # Item-based collaborative filtering
}
model = KNNBasic(sim_options=sim_options)
model.fit(trainset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
# Function to get movie recommendations
def get_movie_recommendations(movie_names, num_recommendations=5):
    # Convert movie names to movie IDs
    movie_ids = [movie_name_to_id.get(name) for name in movie_names if name in movie_name_to_id]

    # Find movie inner IDs from raw IDs
    movie_inner_ids = []
    for movie_id in movie_ids:
        try:
            movie_inner_ids.append(trainset.to_inner_iid(movie_id))
        except ValueError:
            print(f"Movie ID {movie_id} is not part of the trainset. Skipping this movie.")

    if not movie_inner_ids:
        print("No valid movie IDs provided.")
        return []

    # Calculate similarity scores for the provided movies
    similarities = np.zeros(trainset.n_items)
    for inner_id in movie_inner_ids:
        movie_similarities = model.sim[inner_id]
        similarities += movie_similarities

    # Sort the items based on similarity scores
    similar_items = np.argsort(similarities)[::-1]

    # Filter out the provided movies
    recommendations = [trainset.to_raw_iid(inner_id) for inner_id in similar_items if inner_id not in movie_inner_ids]

    # Get movie names for recommendations
    recommended_movie_names = [movie_id_to_name[int(movie_id)] for movie_id in recommendations[:num_recommendations] if int(movie_id) in movie_id_to_name]

    return recommended_movie_names

# %%
# Example usage
movie_names = ["Tomy Story (1995)", "Jumanji (1995)"]  # Provide movie names for which recommendations are needed
recommended_movies = get_movie_recommendations(movie_names, num_recommendations=5)
print(f'Recommended Movies: {recommended_movies}')
# Out:
# Movie ID 1 is not part of the trainset. Skipping this movie.
# Movie ID 2 is not part of the trainset. Skipping this movie.
# No valid movie IDs provided.
# Recommended Movies: []

# %% [markdown]
# # Version 253156714532451 + 2439012348903491283672348981995

# %%
from app.config.enums import Environment
from app.services.sparql_graph import SPARQLGraph

# %%
sparql_graph = SPARQLGraph(Environment.PROD, False)  # Your initialized SPARQL graph
# Out:
# Metadata loaded successfully from JSON files.
# Initializing SPARQLGraph
# Graph loaded with 2056777 triples after 0:00:53.265310

# %%
def get_movie_attributes(movie_id: str) -> dict:
    """
    Queries the knowledge graph to get all attributes and values for a specific movie.
    """
    query = f"""PREFIX wd: <http://www.wikidata.org/entity/>
                    PREFIX wdt: <http://www.wikidata.org/prop/direct/>
                    SELECT ?property ?value
                    WHERE {{
                        wd:{movie_id} ?property ?value .
                    }}"""
    results = sparql_graph.execute_query_plain_answer(query)
    print("Movie Result attributes", results)
    attributes = {}
    for result in results:
        property_, value = result
        if property_ and value:
            attributes[property_] = value
    return attributes

def find_common_attributes(movies: list) -> dict:
    """
    Finds attributes that are common among multiple movies and have the same values.
    """
    movie_attributes = [get_movie_attributes(movie) for movie in movies]

    # Start with the attributes and values of the first movie
    common_attributes = movie_attributes[0]

    # Iterate over the remaining movies
    for attributes in movie_attributes[1:]:
        # Keep only attributes that exist in the current movie and have the same value
        common_attributes = {
            attr: value
            for attr, value in common_attributes.items()
            if attr in attributes and attributes[attr] == value
        }

    return common_attributes


def find_movie_by_attributes(common_attributes, movie_ids: list):
    # Construct SPARQL filters with proper handling for IRIs and literals
    filters = "\n".join(
        f"{format_sparql_value("?movie", attr, value, ".")}" for attr, value in common_attributes.items()
    )
    query = f"""PREFIX wd: <http://www.wikidata.org/entity/>
                PREFIX wdt: <http://www.wikidata.org/prop/direct/>
                SELECT ?movie
                WHERE {{
                    {filters}
                    # Exclude specific movies
                    # FILTER (?movie NOT IN ({", ". join(["wd:" + item for item in movie_ids])}))
                }}
                LIMIT 10"""

    print(f"SPARQL Query:\n{query}")  # Debugging
    response = sparql_graph.execute_query(query)
    response_lbls = [sparql_graph.get_lbl_for_ent(item) for item in response.split("\n") if item]
    print(response_lbls)
    #response_lbl = sparql_graph.get_lbl_for_ent(response)
    print("Response:", response_lbls)  # Print response for debugging
    return response_lbls

def get_similar_movie(movie_ids: list) -> str:
    """
    Finds a movie similar to the given movies based on common attributes.
    """
    common_attributes = find_common_attributes(movie_ids)
    to_delete = []
    for key, value in common_attributes.items():
        relation = sparql_graph.get_lbl_for_ent(str(key))
        val = sparql_graph.get_lbl_for_ent(str(value))
        # if val == "Unknown Label":
        #     to_delete.append(key)
        #     continue

        print(f"{relation}: {val}")  # Debugging

    for key in to_delete:
        del common_attributes[key]

    return find_movie_by_attributes(common_attributes, movie_ids)

def format_sparql_value(prefix, relation, value, suffix):
    """
    Formats a value for use in a SPARQL query.
    - IRIs are enclosed in < >.
    - Strings are enclosed in quotes, optionally with language tags.
    - Dates and other literals use appropriate SPARQL formats.
    """

    # if "http://www.wikidata.org/entity/" in value:
    #     return f"{prefix} wd:{value.split("/")[-1]} {suffix}"
    # elif "http://www.wikidata.org/propt/direct/" in value:
    #     return f"{prefix} wdt:{value.split("/")[-1]} {suffix}"
    # else:
    #     return ""

    return f"{prefix} <{str(relation)}> <{str(value)}> {suffix}"

    # return f"{prefix} wdt:{str(relation).split("/")[-1]} wd:{str(value).split("/")[-1]} {suffix}"

movie_ids = [sparql_graph.get_id_for_movie("The Matrix").split("/")[-1], sparql_graph.get_id_for_movie("Pulp Fiction").split("/")[-1]]
print(f"Found a similar movie: {get_similar_movie(movie_ids)}\n\n")

movie_ids = [sparql_graph.get_id_for_movie("The Lord of the Rings: The Fellowship of the Ring").split("/")[-1], sparql_graph.get_id_for_movie("The Princess Bride").split("/")[-1]]
print(f"Found a similar movie: {get_similar_movie(movie_ids)}\n\n")

movie_ids = [sparql_graph.get_id_for_movie("Avengers: Endgame").split("/")[-1], sparql_graph.get_id_for_movie("Thor: Ragnarok").split("/")[-1]]
print(f"Found a similar movie: {get_similar_movie(movie_ids)}\n\n")

movie_ids = [sparql_graph.get_id_for_movie("Inception").split("/")[-1], sparql_graph.get_id_for_movie("The Matrix").split("/")[-1]]
print(f"Found a similar movie: {get_similar_movie(movie_ids)}\n\n")

movie_ids = [sparql_graph.get_id_for_movie("Kill Bill: Volume 1").split("/")[-1], sparql_graph.get_id_for_movie("Django Unchained").split("/")[-1]]
print(f"Found a similar movie: {get_similar_movie(movie_ids)}\n\n")
# Out:
# Movie Result attributes <rdflib.plugins.sparql.processor.SPARQLResult object at 0x000002A3C7697140>
# Movie Result attributes <rdflib.plugins.sparql.processor.SPARQLResult object at 0x000002A3C77F0590>
# FSK film rating: FSK 16
# aspect ratio: 2.35:1
# instance of: film
# original language of film or TV show: English
# distribution format: video on demand
# color: color
# assessment: Bechdel test
# distributed by: Netflix
# SPARQL Query:
# PREFIX wd: <http://www.wikidata.org/entity/>
#                 PREFIX wdt: <http://www.wikidata.org/prop/direct/>
#                 SELECT ?movie
#                 WHERE {
#                     ?movie <http://www.wikidata.org/prop/direct/P1981> <http://www.wikidata.org/entity/Q20644797> .
# ?movie <http://www.wikidata.org/prop/direct/P2061> <http://www.wikidata.org/entity/Q21062414> .
# ?movie <http://www.wikidata.org/prop/direct/P31> <http://www.wikidata.org/entity/Q11424> .
# ?movie <http://www.wikidata.org/prop/direct/P364> <http://www.wikidata.org/entity/Q1860> .
# ?movie <http://www.wikidata.org/prop/direct/P437> <http://www.wikidata.org/entity/Q723685> .
# ?movie <http://www.wikidata.org/prop/direct/P462> <http://www.wikidata.org/entity/Q22006653> .
# ?movie <http://www.wikidata.org/prop/direct/P5021> <http://www.wikidata.org/entity/Q4165246> .
# ?movie <http://www.wikidata.org/prop/direct/P750> <http://www.wikidata.org/entity/Q907311> .
#                     # Exclude specific movies
#                     # FILTER (?movie NOT IN (wd:Q83495, wd:Q104123))
#                 }
#                 LIMIT 10
# ['The Number 23', 'Daybreakers', 'Contraband', 'Case 39', 'Devil', 'Vanishing on 7th Street', 'Drop Zone', 'Prom Night', 'Room in Rome', 'Blue Ruin']
# Response: ['The Number 23', 'Daybreakers', 'Contraband', 'Case 39', 'Devil', 'Vanishing on 7th Street', 'Drop Zone', 'Prom Night', 'Room in Rome', 'Blue Ruin']
# Found a similar movie: ['The Number 23', 'Daybreakers', 'Contraband', 'Case 39', 'Devil', 'Vanishing on 7th Street', 'Drop Zone', 'Prom Night', 'Room in Rome', 'Blue Ruin']
#
#
# Movie Result attributes <rdflib.plugins.sparql.processor.SPARQLResult object at 0x000002A3C783BC80>
# Movie Result attributes <rdflib.plugins.sparql.processor.SPARQLResult object at 0x000002A3C7847AD0>
# collection: Museum of Modern Art
# CNC film rating (France): no age restriction
# instance of: film
# original language of film or TV show: English
# distribution format: video on demand
# color: color
# assessment: Bechdel test
# distributed by: Netflix
# SPARQL Query:
# PREFIX wd: <http://www.wikidata.org/entity/>
#                 PREFIX wdt: <http://www.wikidata.org/prop/direct/>
#                 SELECT ?movie
#                 WHERE {
#                     ?movie <http://www.wikidata.org/prop/direct/P195> <http://www.wikidata.org/entity/Q188740> .
# ?movie <http://www.wikidata.org/prop/direct/P2758> <http://www.wikidata.org/entity/Q23817729> .
# ?movie <http://www.wikidata.org/prop/direct/P31> <http://www.wikidata.org/entity/Q11424> .
# ?movie <http://www.wikidata.org/prop/direct/P364> <http://www.wikidata.org/entity/Q1860> .
# ?movie <http://www.wikidata.org/prop/direct/P437> <http://www.wikidata.org/entity/Q723685> .
# ?movie <http://www.wikidata.org/prop/direct/P462> <http://www.wikidata.org/entity/Q22006653> .
# ?movie <http://www.wikidata.org/prop/direct/P5021> <http://www.wikidata.org/entity/Q4165246> .
# ?movie <http://www.wikidata.org/prop/direct/P750> <http://www.wikidata.org/entity/Q907311> .
#                     # Exclude specific movies
#                     # FILTER (?movie NOT IN (wd:Q127367, wd:Q506418))
#                 }
#                 LIMIT 10
# ['12 and Holding', 'We Have a Pope', 'Maria Full of Grace', 'Somewhere', 'Klute', 'The Yards', 'Corpse Bride', 'Factotum', 'The Place Beyond the Pines', 'Sleep Dealer']
# Response: ['12 and Holding', 'We Have a Pope', 'Maria Full of Grace', 'Somewhere', 'Klute', 'The Yards', 'Corpse Bride', 'Factotum', 'The Place Beyond the Pines', 'Sleep Dealer']
# Found a similar movie: ['12 and Holding', 'We Have a Pope', 'Maria Full of Grace', 'Somewhere', 'Klute', 'The Yards', 'Corpse Bride', 'Factotum', 'The Place Beyond the Pines', 'Sleep Dealer']
#
#
# Movie Result attributes <rdflib.plugins.sparql.processor.SPARQLResult object at 0x000002A3C784E0C0>
# Movie Result attributes <rdflib.plugins.sparql.processor.SPARQLResult object at 0x000002A3C77F4680>
# takes place in fictional universe: Marvel Cinematic Universe
# MPAA film rating: PG-13
# part of the series: Marvel Cinematic Universe
# aspect ratio: 2.39:1
# NMHH film rating: Category III
# BBFC rating: 12A certificate
# Kijkwijzer rating: 12
# production company: Marvel Studios
# CNC film rating (France): no age restriction
# instance of: film
# ClassInd rating: 12
# ICAA rating: Not recommended for children under 7
# CNC film rating (Romania): A.P. - 12
# original language of film or TV show: English
# distribution format: video on demand
# color: color
# country of origin: United States of America
# assessment: Bechdel test
# IMDA rating: PG13
# Medier̴det rating: For ages 11 and up
# RCQ classification: G
# IFCO rating: 12A
# SPARQL Query:
# PREFIX wd: <http://www.wikidata.org/entity/>
#                 PREFIX wdt: <http://www.wikidata.org/prop/direct/>
#                 SELECT ?movie
#                 WHERE {
#                     ?movie <http://www.wikidata.org/prop/direct/P1434> <http://www.wikidata.org/entity/Q642878> .
# ?movie <http://www.wikidata.org/prop/direct/P1657> <http://www.wikidata.org/entity/Q18665339> .
# ?movie <http://www.wikidata.org/prop/direct/P179> <http://www.wikidata.org/entity/Q642878> .
# ?movie <http://www.wikidata.org/prop/direct/P2061> <http://www.wikidata.org/entity/Q24668302> .
# ?movie <http://www.wikidata.org/prop/direct/P2363> <http://www.wikidata.org/entity/Q21571488> .
# ?movie <http://www.wikidata.org/prop/direct/P2629> <http://www.wikidata.org/entity/Q23301855> .
# ?movie <http://www.wikidata.org/prop/direct/P2684> <http://www.wikidata.org/entity/Q23649983> .
# ?movie <http://www.wikidata.org/prop/direct/P272> <http://www.wikidata.org/entity/Q367466> .
# ?movie <http://www.wikidata.org/prop/direct/P2758> <http://www.wikidata.org/entity/Q23817729> .
# ?movie <http://www.wikidata.org/prop/direct/P31> <http://www.wikidata.org/entity/Q11424> .
# ?movie <http://www.wikidata.org/prop/direct/P3216> <http://www.wikidata.org/entity/Q26678733> .
# ?movie <http://www.wikidata.org/prop/direct/P3306> <http://www.wikidata.org/entity/Q27253940> .
# ?movie <http://www.wikidata.org/prop/direct/P3402> <http://www.wikidata.org/entity/Q27915575> .
# ?movie <http://www.wikidata.org/prop/direct/P364> <http://www.wikidata.org/entity/Q1860> .
# ?movie <http://www.wikidata.org/prop/direct/P437> <http://www.wikidata.org/entity/Q723685> .
# ?movie <http://www.wikidata.org/prop/direct/P462> <http://www.wikidata.org/entity/Q22006653> .
# ?movie <http://www.wikidata.org/prop/direct/P495> <http://www.wikidata.org/entity/Q30> .
# ?movie <http://www.wikidata.org/prop/direct/P5021> <http://www.wikidata.org/entity/Q4165246> .
# ?movie <http://www.wikidata.org/prop/direct/P5201> <http://www.wikidata.org/entity/Q52382301> .
# ?movie <http://www.wikidata.org/prop/direct/P5970> <http://www.wikidata.org/entity/Q56887490> .
# ?movie <http://www.wikidata.org/prop/direct/P6658> <http://www.wikidata.org/entity/Q62365366> .
# ?movie <http://www.wikidata.org/prop/direct/P7573> <http://www.wikidata.org/entity/Q74434531> .
#                     # Exclude specific movies
#                     # FILTER (?movie NOT IN (wd:Q23781155, wd:Q22665878))
#                 }
#                 LIMIT 10
# ['Thor: Ragnarok', 'Doctor Strange', 'Avengers: Endgame']
# Response: ['Thor: Ragnarok', 'Doctor Strange', 'Avengers: Endgame']
# Found a similar movie: ['Thor: Ragnarok', 'Doctor Strange', 'Avengers: Endgame']
#
#
# Movie Result attributes <rdflib.plugins.sparql.processor.SPARQLResult object at 0x000002A3C7839940>
# Movie Result attributes <rdflib.plugins.sparql.processor.SPARQLResult object at 0x000002A3C77F5220>
# Unknown Label: Unknown Label
# nominated for: Academy Award for Best Sound
# award received: Academy Award for Best Sound
# Filmiroda rating: Category III
# instance of: film
# distribution format: video on demand
# color: color
# assessment: Bechdel test
# Medier̴det rating: For ages 15 and up
# distributed by: Netflix
# main subject: telepresence
# SPARQL Query:
# PREFIX wd: <http://www.wikidata.org/entity/>
#                 PREFIX wdt: <http://www.wikidata.org/prop/direct/>
#                 SELECT ?movie
#                 WHERE {
#                     ?movie <http://ddis.ch/atai/tag> <violence> .
# ?movie <http://www.wikidata.org/prop/direct/P1411> <http://www.wikidata.org/entity/Q830079> .
# ?movie <http://www.wikidata.org/prop/direct/P166> <http://www.wikidata.org/entity/Q830079> .
# ?movie <http://www.wikidata.org/prop/direct/P2747> <http://www.wikidata.org/entity/Q23830578> .
# ?movie <http://www.wikidata.org/prop/direct/P31> <http://www.wikidata.org/entity/Q11424> .
# ?movie <http://www.wikidata.org/prop/direct/P437> <http://www.wikidata.org/entity/Q723685> .
# ?movie <http://www.wikidata.org/prop/direct/P462> <http://www.wikidata.org/entity/Q22006653> .
# ?movie <http://www.wikidata.org/prop/direct/P5021> <http://www.wikidata.org/entity/Q4165246> .
# ?movie <http://www.wikidata.org/prop/direct/P5970> <http://www.wikidata.org/entity/Q56887761> .
# ?movie <http://www.wikidata.org/prop/direct/P750> <http://www.wikidata.org/entity/Q907311> .
# ?movie <http://www.wikidata.org/prop/direct/P921> <http://www.wikidata.org/entity/Q544830> .
#                     # Exclude specific movies
#                     # FILTER (?movie NOT IN (wd:Q25188, wd:Q83495))
#                 }
#                 LIMIT 10
# []
# Response: []
# Found a similar movie: []
#
#
# Movie Result attributes Expected SelectQuery, found 'wd'  (at char 212), (line:5, col:25)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 116
#     113 print(f"Found a similar movie: {get_similar_movie(movie_ids)}\n\n")
#     115 movie_ids = [sparql_graph.get_id_for_movie("Kill Bill: Volume 1").split("/")[-1], sparql_graph.get_id_for_movie("Django Unchained").split("/")[-1]]
# --> 116 print(f"Found a similar movie: {get_similar_movie(movie_ids)}\n\n")
#
# Cell In[4], line 68, in get_similar_movie(movie_ids)
#      64 def get_similar_movie(movie_ids: list) -> str:
#      65     """
#      66     Finds a movie similar to the given movies based on common attributes.
#      67     """
# ---> 68     common_attributes = find_common_attributes(movie_ids)
#      69     to_delete = []
#      70     for key, value in common_attributes.items():
#
# Cell In[4], line 24, in find_common_attributes(movies)
#      20 def find_common_attributes(movies: list) -> dict:
#      21     """
#      22     Finds attributes that are common among multiple movies and have the same values.
#      23     """
# ---> 24     movie_attributes = [get_movie_attributes(movie) for movie in movies]
#      26     # Start with the attributes and values of the first movie
#      27     common_attributes = movie_attributes[0]
#
# Cell In[4], line 15, in get_movie_attributes(movie_id)
#      13 attributes = {}
#      14 for result in results:
# ---> 15     property_, value = result
#      16     if property_ and value:
#      17         attributes[property_] = value
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
def get_movie_attributes(movie_id: str) -> dict:
    """
    Queries the knowledge graph to get all attributes and values for a specific movie.
    """
    query = f"""PREFIX wd: <http://www.wikidata.org/entity/>
                    PREFIX wdt: <http://www.wikidata.org/prop/direct/>
                    SELECT ?property ?value
                    WHERE {{
                        wd:{movie_id} ?property ?value .
                    }}"""
    results = sparql_graph.execute_query_plain_answer(query)
    print("Movie Result attributes", results)
    attributes = {}
    for result in results:
        print(result)
        property_, value = result
        if property_ and value:
            attributes[property_] = value
    return attributes

def find_common_attributes(movies: list) -> dict:
    """
    Finds attributes that are common among multiple movies and have the same values.
    """
    movie_attributes = [get_movie_attributes(movie) for movie in movies]

    # Start with the attributes and values of the first movie
    common_attributes = movie_attributes[0]

    # Iterate over the remaining movies
    for attributes in movie_attributes[1:]:
        # Keep only attributes that exist in the current movie and have the same value
        common_attributes = {
            attr: value
            for attr, value in common_attributes.items()
            if attr in attributes and attributes[attr] == value
        }

    return common_attributes


def find_movie_by_attributes(common_attributes, movie_ids: list):
    # Construct SPARQL filters with proper handling for IRIs and literals
    filters = "\n".join(
        f"{format_sparql_value("?movie", attr, value, ".")}" for attr, value in common_attributes.items()
    )
    query = f"""PREFIX wd: <http://www.wikidata.org/entity/>
                PREFIX wdt: <http://www.wikidata.org/prop/direct/>
                SELECT ?movie
                WHERE {{
                    {filters}
                    # Exclude specific movies
                    # FILTER (?movie NOT IN ({", ". join(["wd:" + item for item in movie_ids])}))
                }}
                LIMIT 10"""

    print(f"SPARQL Query:\n{query}")  # Debugging
    response = sparql_graph.execute_query(query)
    response_lbls = [sparql_graph.get_lbl_for_ent(item) for item in response.split("\n") if item]
    print(response_lbls)
    #response_lbl = sparql_graph.get_lbl_for_ent(response)
    print("Response:", response_lbls)  # Print response for debugging
    return response

def get_similar_movie(movie_ids: list) -> str:
    """
    Finds a movie similar to the given movies based on common attributes.
    """
    common_attributes = find_common_attributes(movie_ids)
    to_delete = []
    for key, value in common_attributes.items():
        relation = sparql_graph.get_lbl_for_ent(str(key))
        val = sparql_graph.get_lbl_for_ent(str(value))
        if "http" in val:
            to_delete.append(key)
            continue

        print(f"{relation}: {val}")  # Debugging

    for key in to_delete:
        del common_attributes[key]

    return find_movie_by_attributes(common_attributes, movie_ids)

def format_sparql_value(prefix, relation, value, suffix):
    """
    Formats a value for use in a SPARQL query.
    - IRIs are enclosed in < >.
    - Strings are enclosed in quotes, optionally with language tags.
    - Dates and other literals use appropriate SPARQL formats.
    """

    # if "http://www.wikidata.org/entity/" in value:
    #     return f"{prefix} wd:{value.split("/")[-1]} {suffix}"
    # elif "http://www.wikidata.org/propt/direct/" in value:
    #     return f"{prefix} wdt:{value.split("/")[-1]} {suffix}"
    # else:
    #     return ""

    if "http" in str(value):
        value = f"<{str(value)}>"
    else:
        value = f"\"{str(value)}\"@en"

    return f"{prefix} <{str(relation)}> {value} {suffix}"

    # return f"{prefix} wdt:{str(relation).split("/")[-1]} wd:{str(value).split("/")[-1]} {suffix}"

movie_ids = [sparql_graph.get_id_for_movie("The Matrix").split("/")[-1], sparql_graph.get_id_for_movie("Pulp Fiction").split("/")[-1]]
print(f"Found a similar movie: {get_similar_movie(movie_ids)}\n\n")

movie_ids = [sparql_graph.get_id_for_movie("The Lord of the Rings: The Fellowship of the Ring").split("/")[-1], sparql_graph.get_id_for_movie("The Princess Bride").split("/")[-1]]
print(f"Found a similar movie: {get_similar_movie(movie_ids)}\n\n")

movie_ids = [sparql_graph.get_id_for_movie("Avengers: Endgame").split("/")[-1], sparql_graph.get_id_for_movie("Thor: Ragnarok").split("/")[-1]]
print(f"Found a similar movie: {get_similar_movie(movie_ids)}\n\n")

movie_ids = [sparql_graph.get_id_for_movie("Inception").split("/")[-1], sparql_graph.get_id_for_movie("The Matrix").split("/")[-1]]
print(f"Found a similar movie: {get_similar_movie(movie_ids)}\n\n")

movie_ids = [sparql_graph.get_id_for_movie("Kill Bill: Volume 1").split("/")[-1], sparql_graph.get_id_for_movie("Django Unchained").split("/")[-1]]
print(f"Found a similar movie: {get_similar_movie(movie_ids)}\n\n")
# Out:
# Movie Result attributes <rdflib.plugins.sparql.processor.SPARQLResult object at 0x000002A3C78F9A90>
# (rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('The Matrix', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('action', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('alternate_reality', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('atmospheric', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('boring', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('cult', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('dark', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('dramatic', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('fantasy', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('murder', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('mystery', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('neo_noir', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('philosophical', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('psychedelic', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('romantic', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('sci-fi', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('thought-provoking', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('violence', lang='en'))
# (rdflib.term.URIRef('http://schema.org/description'), rdflib.term.Literal('1999 American science fiction action thriller film', lang='en'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1040'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q139384'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1343'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q105406968'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1343'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q77855044'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1341051'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q174526'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q185867'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q188473'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q20443008'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2484376'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3990883'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q471839'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q281939'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q393686'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q488645'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q830079'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1431'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q539718'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1434'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q20019907'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P156'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q189600'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1236595'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q18219789'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q193048'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q206890'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q21870719'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2424724'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q258604'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2616690'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q296883'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2985403'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3324448'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3391203'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q42204'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q43416'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q455234'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q4882899'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q6306950'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q862673'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q944529'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1657'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q18665344'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1131772'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1265702'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q281939'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q393686'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q488645'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q739633'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q787127'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q823422'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q830079'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P179'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1210827'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P18'), rdflib.term.Literal('https://commons.wikimedia.org/wiki/File:The.Matrix.glmatrix.1.png', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1981'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q20644797'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2061'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q21062414'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2079'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q78612378'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2142'), rdflib.term.Literal('463517383', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P272'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1188938'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P272'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q126399'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P272'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q622668'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2747'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q23830578'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2756'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q23790275'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2758'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q23817729'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2758'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q23817739'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q11424'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P344'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q795025'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345'), rdflib.term.Literal('tt0133093', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P364'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1860'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P437'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q723685'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P462'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q22006653'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P495'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q30'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P495'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q408'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P4969'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q335340'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P5021'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q105776216'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P5021'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q4165246'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P57'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q195719'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P577'), rdflib.term.Literal('1999-03-31', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#date')))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P58'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q195719'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P5970'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q56887761'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P750'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1097348'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P750'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q126399'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P750'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q65359104'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P750'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q80948336'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P750'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q907311'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P8345'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q13014087'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P915'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3130'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P915'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q408'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P915'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q62'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q11660'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2798820'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q544830'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P941'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1066948'))
# Movie Result attributes <rdflib.plugins.sparql.processor.SPARQLResult object at 0x000002A3C7906E40>
# (rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Pulp Fiction', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('action', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('atmospheric', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('clever', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('comedy', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('cult', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('dark', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('dramatic', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('entertaining', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('flashback', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('humor', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('murder', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('mystery', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('neo_noir', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('philosophical', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('plot_twist', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('psychedelic', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('realism', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('revenge', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('satire', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('storytelling', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('stupid', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('suspenseful', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('thought-provoking', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('violence', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('western', lang='en'))
# (rdflib.term.URIRef('http://schema.org/description'), rdflib.term.Literal('1994 American crime film directed by Quentin Tarantino', lang='en'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1040'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q273379'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q130232'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2484376'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q459290'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q7444356'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1011509'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q102427'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q103360'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q103916'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q106291'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q106301'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1170507'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1260789'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1315008'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1320315'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q139184'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q165313'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1720784'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1967719'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1967731'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2294693'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2295041'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2544859'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q281939'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3404521'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3404523'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q400007'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q41375'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q41417'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q4220897'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q4220898'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q4220900'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q4220901'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q4824149'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q499789'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q5280675'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q540977'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q548389'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q586356'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q593098'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q654620'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q687123'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q6978541'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q723830'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q739633'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q787131'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q787145'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q822907'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q849124'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q900414'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1431'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q13409484'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1431'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2325642'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1431'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q26806'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1016897'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q104061'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q109232'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1209753'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q125017'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1368224'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1563838'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q164534'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q172678'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q185051'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q191132'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q203804'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2263306'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q235115'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q238483'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q240774'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2434817'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q254431'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2680'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q270774'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2924399'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2926038'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q310315'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q318267'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3193117'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3241353'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q356541'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3772'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3856171'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3973186'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q432437'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q453973'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q514913'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q7647898'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q80938'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1170507'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1315008'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1720784'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1789102'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q179808'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1868950'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2295041'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2544859'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3404523'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q41375'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q41417'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q4220897'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q503034'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q505449'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q540977'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q548389'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q696972'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q696998'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q6978541'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q823422'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q849124'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q952914'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P18'), rdflib.term.Literal('https://commons.wikimedia.org/wiki/File:Pulp_Fiction_Logo.png', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P195'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q188740'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1981'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q20644797'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2061'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q21062414'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2142'), rdflib.term.Literal('213928762', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2283'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2894685'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2515'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1627038'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2554'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3018955'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P272'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q300323'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P272'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3177524'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P272'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q465449'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2747'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q23830579'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2756'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q23790279'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2758'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q23817740'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q11424'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P3306'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q27253952'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P344'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q515568'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345'), rdflib.term.Literal('tt0110912', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P364'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1860'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P437'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q723685'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P462'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q22006653'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P495'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q30'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P5021'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q105776216'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P5021'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q4165246'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P57'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3772'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P577'), rdflib.term.Literal('1994-05-21', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#date')))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P58'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3772'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P58'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q450720'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P5970'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q80655145'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P674'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q15427568'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P674'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q16585660'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P674'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q19777775'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P674'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3900376'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P750'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q17126013'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P750'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q80948336'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P750'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q907311'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P840'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q65'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P915'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1509'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P915'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q65'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q46952'))
# FSK film rating: FSK 16
# aspect ratio: 2.35:1
# instance of: film
# original language of film or TV show: English
# distribution format: video on demand
# color: color
# assessment: Bechdel test
# distributed by: Netflix
# SPARQL Query:
# PREFIX wd: <http://www.wikidata.org/entity/>
#                 PREFIX wdt: <http://www.wikidata.org/prop/direct/>
#                 SELECT ?movie
#                 WHERE {
#                     ?movie <http://www.wikidata.org/prop/direct/P1981> <http://www.wikidata.org/entity/Q20644797> .
# ?movie <http://www.wikidata.org/prop/direct/P2061> <http://www.wikidata.org/entity/Q21062414> .
# ?movie <http://www.wikidata.org/prop/direct/P31> <http://www.wikidata.org/entity/Q11424> .
# ?movie <http://www.wikidata.org/prop/direct/P364> <http://www.wikidata.org/entity/Q1860> .
# ?movie <http://www.wikidata.org/prop/direct/P437> <http://www.wikidata.org/entity/Q723685> .
# ?movie <http://www.wikidata.org/prop/direct/P462> <http://www.wikidata.org/entity/Q22006653> .
# ?movie <http://www.wikidata.org/prop/direct/P5021> <http://www.wikidata.org/entity/Q4165246> .
# ?movie <http://www.wikidata.org/prop/direct/P750> <http://www.wikidata.org/entity/Q907311> .
#                     # Exclude specific movies
#                     # FILTER (?movie NOT IN (wd:Q83495, wd:Q104123))
#                 }
#                 LIMIT 10
# ['The Number 23', 'Daybreakers', 'Contraband', 'Case 39', 'Devil', 'Vanishing on 7th Street', 'Drop Zone', 'Prom Night', 'Room in Rome', 'Blue Ruin']
# Response: ['The Number 23', 'Daybreakers', 'Contraband', 'Case 39', 'Devil', 'Vanishing on 7th Street', 'Drop Zone', 'Prom Night', 'Room in Rome', 'Blue Ruin']
# Found a similar movie: http://www.wikidata.org/entity/Q1123479
# http://www.wikidata.org/entity/Q1128499
# http://www.wikidata.org/entity/Q1129080
# http://www.wikidata.org/entity/Q1164919
# http://www.wikidata.org/entity/Q1206820
# http://www.wikidata.org/entity/Q1213427
# http://www.wikidata.org/entity/Q1260289
# http://www.wikidata.org/entity/Q1301177
# http://www.wikidata.org/entity/Q1306557
# http://www.wikidata.org/entity/Q13380375
#
#
# Movie Result attributes <rdflib.plugins.sparql.processor.SPARQLResult object at 0x000002A3C852FEC0>
# (rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('The Lord of the Rings: The Fellowship of the Ring', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/rating'), rdflib.term.Literal('8.8', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal')))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('action', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('atmospheric', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('boring', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('cult', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('fantasy', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('flashback', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('good_versus_evil', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('horror', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('mystery', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('romantic', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('stupid', lang='en'))
# (rdflib.term.URIRef('http://schema.org/description'), rdflib.term.Literal('2001 film directed by Peter Jackson', lang='en'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1040'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q8293'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q130232'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q157394'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q188473'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q319221'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q52207399'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q102427'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q103360'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q106291'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q107258'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q112243'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q131520'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q277536'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q277751'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q281939'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q393686'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q487136'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q488651'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q830079'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1431'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q421488'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1431'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q531599'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1431'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q6832375'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1431'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q888311'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P144'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q208002'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P156'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q164963'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1388807'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q152165'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q16455'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1655613'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q168763'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q170510'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q171363'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q180338'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q189351'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q191104'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q206922'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q223091'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2598175'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q270878'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q276425'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q315118'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q326323'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3330820'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3390280'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q339036'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3390514'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q339083'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q42204'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q44467'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q4465'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q469179'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q483771'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q5363234'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q737607'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q80966'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q910486'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q131520'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q139184'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q393686'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q487136'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q488651'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P175'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q207773'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P179'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q190214'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P179'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q26214973'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1877'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q892'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P195'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q188740'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1981'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q20644796'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2061'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q21062414'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2142'), rdflib.term.Literal('883726270', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2283'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q568723'))
# ...
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('murder', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('mystery', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('neo_noir', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('philosophical', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('psychedelic', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('romantic', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('sci-fi', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('thought-provoking', lang='en'))
# (rdflib.term.URIRef('http://ddis.ch/atai/tag'), rdflib.term.Literal('violence', lang='en'))
# (rdflib.term.URIRef('http://schema.org/description'), rdflib.term.Literal('1999 American science fiction action thriller film', lang='en'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1040'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q139384'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1343'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q105406968'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1343'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q77855044'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1341051'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q174526'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q185867'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q188473'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q20443008'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2484376'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3990883'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P136'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q471839'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q281939'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q393686'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q488645'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1411'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q830079'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1431'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q539718'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1434'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q20019907'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P156'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q189600'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1236595'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q18219789'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q193048'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q206890'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q21870719'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2424724'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q258604'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2616690'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q296883'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2985403'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3324448'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3391203'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q42204'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q43416'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q455234'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q4882899'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q6306950'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q862673'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q944529'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1657'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q18665344'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1131772'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1265702'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q281939'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q393686'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q488645'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q739633'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q787127'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q823422'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P166'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q830079'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P179'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1210827'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P18'), rdflib.term.Literal('https://commons.wikimedia.org/wiki/File:The.Matrix.glmatrix.1.png', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1981'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q20644797'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2061'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q21062414'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2079'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q78612378'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2142'), rdflib.term.Literal('463517383', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P272'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1188938'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P272'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q126399'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P272'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q622668'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2747'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q23830578'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2756'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q23790275'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2758'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q23817729'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2758'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q23817739'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P31'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q11424'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P344'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q795025'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P345'), rdflib.term.Literal('tt0133093', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P364'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1860'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P437'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q723685'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P462'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q22006653'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P495'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q30'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P495'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q408'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P4969'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q335340'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P5021'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q105776216'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P5021'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q4165246'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P57'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q195719'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P577'), rdflib.term.Literal('1999-03-31', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#date')))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P58'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q195719'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P5970'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q56887761'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P750'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1097348'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P750'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q126399'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P750'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q65359104'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P750'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q80948336'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P750'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q907311'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P8345'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q13014087'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P915'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q3130'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P915'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q408'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P915'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q62'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q11660'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q2798820'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q544830'))
# (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P941'), rdflib.term.URIRef('http://www.wikidata.org/entity/Q1066948'))
# Unknown Label: Unknown Label
# nominated for: Academy Award for Best Sound
# award received: Academy Award for Best Sound
# Filmiroda rating: Category III
# instance of: film
# distribution format: video on demand
# color: color
# assessment: Bechdel test
# Medier̴det rating: For ages 15 and up
# distributed by: Netflix
# main subject: telepresence
# SPARQL Query:
# PREFIX wd: <http://www.wikidata.org/entity/>
#                 PREFIX wdt: <http://www.wikidata.org/prop/direct/>
#                 SELECT ?movie
#                 WHERE {
#                     ?movie <http://ddis.ch/atai/tag> "violence"@en .
# ?movie <http://www.wikidata.org/prop/direct/P1411> <http://www.wikidata.org/entity/Q830079> .
# ?movie <http://www.wikidata.org/prop/direct/P166> <http://www.wikidata.org/entity/Q830079> .
# ?movie <http://www.wikidata.org/prop/direct/P2747> <http://www.wikidata.org/entity/Q23830578> .
# ?movie <http://www.wikidata.org/prop/direct/P31> <http://www.wikidata.org/entity/Q11424> .
# ?movie <http://www.wikidata.org/prop/direct/P437> <http://www.wikidata.org/entity/Q723685> .
# ?movie <http://www.wikidata.org/prop/direct/P462> <http://www.wikidata.org/entity/Q22006653> .
# ?movie <http://www.wikidata.org/prop/direct/P5021> <http://www.wikidata.org/entity/Q4165246> .
# ?movie <http://www.wikidata.org/prop/direct/P5970> <http://www.wikidata.org/entity/Q56887761> .
# ?movie <http://www.wikidata.org/prop/direct/P750> <http://www.wikidata.org/entity/Q907311> .
# ?movie <http://www.wikidata.org/prop/direct/P921> <http://www.wikidata.org/entity/Q544830> .
#                     # Exclude specific movies
#                     # FILTER (?movie NOT IN (wd:Q25188, wd:Q83495))
#                 }
#                 LIMIT 10
# ['Inception', 'The Matrix']
# Response: ['Inception', 'The Matrix']
# Found a similar movie: http://www.wikidata.org/entity/Q25188
# http://www.wikidata.org/entity/Q83495
#
#
# Movie Result attributes Expected SelectQuery, found 'wd'  (at char 212), (line:5, col:25)
# E
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 122
#     119 print(f"Found a similar movie: {get_similar_movie(movie_ids)}\n\n")
#     121 movie_ids = [sparql_graph.get_id_for_movie("Kill Bill: Volume 1").split("/")[-1], sparql_graph.get_id_for_movie("Django Unchained").split("/")[-1]]
# --> 122 print(f"Found a similar movie: {get_similar_movie(movie_ids)}\n\n")
#
# Cell In[17], line 69, in get_similar_movie(movie_ids)
#      65 def get_similar_movie(movie_ids: list) -> str:
#      66     """
#      67     Finds a movie similar to the given movies based on common attributes.
#      68     """
# ---> 69     common_attributes = find_common_attributes(movie_ids)
#      70     to_delete = []
#      71     for key, value in common_attributes.items():
#
# Cell In[17], line 25, in find_common_attributes(movies)
#      21 def find_common_attributes(movies: list) -> dict:
#      22     """
#      23     Finds attributes that are common among multiple movies and have the same values.
#      24     """
# ---> 25     movie_attributes = [get_movie_attributes(movie) for movie in movies]
#      27     # Start with the attributes and values of the first movie
#      28     common_attributes = movie_attributes[0]
#
# Cell In[17], line 16, in get_movie_attributes(movie_id)
#      14 for result in results:
#      15     print(result)
# ---> 16     property_, value = result
#      17     if property_ and value:
#      18         attributes[property_] = value
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %% [markdown]
# # Version 253156714532451 + 2439012348903491283672348981995 + 458349759384573904

# %%
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors

# %%
ml_ratings = pd.read_csv('../useful_dataset/recommendations/ratings.csv', usecols=['userId', 'movieId', 'rating'])
ml_matrix = ml_ratings.pivot(index='movieId', columns='userId', values='rating').filln(0)
ml_csr = csr_matrix(ml_matrix.values)
movie_df = pd.read_csv('../useful_dataset/recommendations/movies.csv', usecols=['movieId', 'title'])

knn = NearestNeighbors(metric='cosine', algorithm='brute', n_neighbors=17)
knn.fit(ml_csr[:, :])

# %% [markdown]
# # Something totally different

# %%
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
import pandas as pd

# %%
# Step 1: Load the dataset
def load_movielens_data():
    # Load the MovieLens 100k dataset (ratings.csv)
    ratings = pd.read_csv("../useful_dataset/recommendations/ratings.csv")
    movies = pd.read_csv("../useful_dataset/recommendations/movies.csv")

    # Merge ratings and movies
    data = pd.merge(ratings, movies, on='movieId')
    return data, ratings, movies

data, ratings, movies = load_movielens_data()

# %%
# Step 2: Train a collaborative filtering model
def train_model(ratings):
    reader = Reader(rating_scale=(0.5, 5.0))
    data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader)
    trainset, testset = train_test_split(data, test_size=0.25)

    # Use SVD (Singular Value Decomposition)
    algo = SVD()
    algo.fit(trainset)
    return algo

algo = train_model(ratings)

# %%
# Step 3: Recommend a movie based on input movies
def recommend_movie(movie_titles, algo, data, ratings, movies):
    # Find movieIds for given titles
    movie_ids = movies[movies['title'].isin(movie_titles)]['movieId'].tolist()
    if not movie_ids:
        return "Movies not found in the dataset."

    # Find users who rated these movies highly
    users = ratings[ratings['movieId'].isin(movie_ids) & (ratings['rating'] >= 4.0)]['userId'].unique()

    # Predict ratings for these users for all movies
    all_movie_ids = movies['movieId'].unique()
    predicted_ratings = []
    for user in users:
        for movie_id in all_movie_ids:
            if movie_id not in movie_ids:  # Avoid recommending input movies
                pred = algo.predict(user, movie_id)
                predicted_ratings.append((movie_id, pred.est))

    # Sort by predicted rating
    predicted_ratings.sort(key=lambda x: x[1], reverse=True)

    # Return the top recommended movie
    recommended_movie_id = predicted_ratings[0][0]
    recommended_movie_title = movies[movies['movieId'] == recommended_movie_id]['title'].iloc[0]
    return recommended_movie_title

# %%
# Main script
input_movies = ["Toy Story (1995)", "Jumanji (1995)"]  # Example movies
recommended_movie = recommend_movie(input_movies, algo, data, ratings, movies)
print(f"Recommended Movie: {recommended_movie}")
# Out:
# Recommended Movie: Usual Suspects, The (1995)
